# %% [markdown]
# ## Applying Chi2 Algorithm - For Dimension Reduction
# ---
#
# - Get First `K` Attributes / Columns Which are More Important for Prediction than others and also has greater *chi2* Value

# %% [markdown]
# ### Using IRIS Data set
# ---

# %%
# Load libraries
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
#Load Data
# Load iris data
iris = load_iris()

# Create features and target
X = iris.data
y = iris.target

# Convert to categorical data by converting data to integers
X = X.astype(int)

#Compare Chi-Squared Statistics
# Select two features with highest chi-squared statistics
chi2_selector = SelectKBest(chi2, k=2)
X_kbest = chi2_selector.fit_transform(X, y)
# Show results
print('Original number of features:', X.shape[1])
print('Reduced number of features:', X_kbest.shape[1])
# Out:
# ('Original number of features:', 4)
# ('Reduced number of features:', 2)

# %%
chi2_selector.get_params()
# Out:
# {'k': 2,
#  'score_func': <function sklearn.feature_selection.univariate_selection.chi2>}

# %%
idxs_selected = chi2_selector.get_support(indices=True)
# Create new dataframe with only desired columns, or overwrite existing
print idxs_selected
# Out:
# [2 3]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

# %%
print df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# ### Important Columns Are:
# ---

# %%
print df.columns[idxs_selected]
# Out:
# Index([u'petal length (cm)', u'petal width (cm)'], dtype='object')
